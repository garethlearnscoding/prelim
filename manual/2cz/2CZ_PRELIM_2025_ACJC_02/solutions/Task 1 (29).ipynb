# %%
def check_magic(arr):
    
    n = len(arr) # 1 mark: defining variables (can award if used correctly later)
    magic_sum = n*(n**2 + 1)//2
    
    flag = True
    #1 mark: flag to check if all integers from 1 to n**2 (inclusive) are inside
    
    for i in range(1, size**2 + 1):
        
        found_i = False #  1 mark: looks for i inside the array
        
        for row in arr:
            for item in row:
                if item == i:
                    found_i = True # 1 mark
        
        if found_i == False:
            flag = False
    
    if flag == False: # 1 mark
        return False
    
    # check row sum:
    for row in arr: # 1 mark
        row_sum = 0
        for item in row:
            row_sum += item # 1 mark
        if row_sum != magic_sum:
            return False
    
    # check column sum:
    for i in range(n): # 1 mark: i is column index
        col_sum = 0
        for j in range(n): # 1 mark: j is row index
            col_sum += arr[j][i]
        if col_sum != magic_sum:
            return False
    
    # check diagonals:
    dia1_sum = 0
    dia2_sum = 0
    for i in range(n):
        dia1_sum += arr[i][i] # 1 mark
        dia2_sum += arr[i][n-1-i]
    if dia1_sum != magic_sum or dia2_sum != magic_sum: # 1 mark
        return False

# Total: 11 marks

def check_file(filename):
    f = open(filename) # 1 mark
    arr = []
    for line in f:
        line = line.strip().split() # 1 mark
        row = []
        for item in line:
            row.append(int(item)) # 1 mark
        arr.append(row) # 1 mark
    f.close()
    
    return check_magic(arr) # 1 mark

# Total: 5 marks

# Checking text files and output: 2 marks

def make_magic(n):
    
    array = [] # 1 mark: create array
    for i in range(n):
        row = []
        for j in range(n):
            row.append(0) # 1 mark: placeholder
        array.append(row)
    
    curr_row = (n-1) // 2 # 1 mark: starting square
    curr_col = 0
    
    for i in range(1, n**2 + 1): # 1 mark: iteration
        array[curr_row][curr_col] = i
        
        curr_row = (curr_row - 1) % n # 1 mark
        curr_col = (curr_col + 1) % n
        
        if array[curr_row][curr_col] != 0: # 1 mark (or consider i % n)
            curr_row = (curr_row + 2) % n
            curr_col = (curr_col - 1) % n
    
    return array

# Total: 6 marks

arr = make_magic(9) # 1 mark

f_write = open("Task1-4.csv", "w") # 1 mark
for row in arr: # 1 mark
    to_write = ""
    for item in row:
        to_write += str(item) + "," # 1 mark
    to_write = to_write[:-1] + "/n"
    f_write.write(to_write) # 1 mark
f.close()

# Total: 5 marks

# total for this question: 29 marks
