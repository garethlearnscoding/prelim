# %%
# Task 4.1: Importing New Patient Records
import sqlite3

# Connect to the CLINIC.db database
conn = sqlite3.connect('CLINIC.db')
cursor = conn.cursor()

with open('datafiles/PATIENT.txt', 'r') as file:
    for line in file:
        data = line.strip().split(',')
        query = f'INSERT INTO PATIENT ("PatientID", "Name", "DOB", "ContactNumber") VALUES (?,?,?,?)'
        cursor.execute(query, data)
# Close file automatically

with open('datafiles/STAFF.txt', 'r') as file:
    for line in file:
        data = line.strip().split(',')
        query = f"INSERT INTO STAFF ('StaffID', 'Name', 'Role', 'Specialization') VALUES (?,?,?,?)"
        cursor.execute(query, data)
# Close file automatically

with open('datafiles/APPOINTMENT.txt', 'r') as file:
    for line in file:
        data = line.strip().split(',')
        query = f"INSERT INTO APPOINTMENT ('AppointmentID', 'PatientID', 'StaffID', 'AppointmentDate', 'Diagnosis') VALUES (?,?,?,?,?)"
        cursor.execute(query, data)
# Close file automatically

# Commit the transactions and close the connection
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22760\928016109.py in <module>
#      10         data = line.strip().split(',')
#      11         query = f'INSERT INTO PATIENT ("PatientID", "Name", "DOB", "ContactNumber") VALUES (?,?,?,?)'
# ---> 12         cursor.execute(query, data)
#      13 # Close file automatically
#      14
#
# IntegrityError: UNIQUE constraint failed: Patient.PatientID

# %%
# Task 4.2: Retrieving a 2D Array of Appointment Data
import sqlite3

conn = sqlite3.connect('CLINIC.db') # Connect to database
cursor = conn.cursor()              # Create cursor object

cursor.execute('''
    SELECT Appointment.AppointmentID, Patient.PatientID, Patient.Name, Staff.StaffID, Staff.Name, Appointment.AppointmentDate, Appointment.Diagnosis 
    FROM Appointment
    INNER JOIN Patient ON Appointment.PatientID = Patient.PatientID
    INNER JOIN Staff ON Appointment.StaffID = Staff.StaffID
''')
appointments = cursor.fetchall()  # Fetch all results from SQL query executed

from pprint import pprint
pprint(appointments)    # Print appointements in readable format
print()

conn.close()    # Close database connection
# Out:
# [('A001',
#   'P027',
#   'Fiona Tan',
#   'S013',
#   'Dr. Marcus Tan',
#   '01/08/2024',
#   'Cardiology'),
#  ('A002',
#   'P031',
#   'Rachel Tan',
#   'S002',
#   'Dr. Lim Wei',
#   '02/08/2024',
#   'Orthopedics'),
#  ('A003',
#   'P014',
#   'Chong Wei',
#   'S012',
#   'Dr. Mei Ling',
#   '03/08/2024',
#   'Endocrinology'),
#  ('A004',
#   'P043',
#   'Li Ping',
#   'S004',
#   'Dr. Chen Ming',
#   '04/08/2024',
#   'Neurology'),
#  ('A006',
#   'P023',
#   'Anwar Ali',
#   'S006',
#   'Dr. Tan Cheng',
#   '06/08/2024',
#   'Orthopedics'),
#  ('A007',
#   'P012',
#   'Amira Hussain',
#   'S007',
#   'Dr. Kevin Lim',
#   '07/08/2024',
#   'General Surgery'),
#  ('A008',
#   'P037',
#   'Ah Fook',
#   'S008',
#   'Dr. Samuel Lee',
#   '08/08/2024',
#   'Cardiology'),
#  ('A009', 'P048', 'Sam Lee', 'S009', 'Dr. Ryan Tan', '09/08/2024', 'Neurology'),
#  ('A010',
#   'P026',
#   'Victor Cheong',
#   'S010',
#   'Dr. Ethan Ng',
#   '10/08/2024',
#   'Pediatrics'),
#  ('A011',
#   'P042',
#   'Ali Abdullah',
#   'S011',
#   'Dr. John Tan',
#   '11/08/2024',
#   'Oncology'),
#  ('A012',
#   'P040',
#   'Jamie Ong',
#   'S012',
#   'Dr. Mei Ling',
#   '12/08/2024',
#   'Endocrinology'),
#  ('A013',
#   'P010',
#   'David Tan',
#   'S013',
#   'Dr. Marcus Tan',
#   '13/08/2024',
#   'Cardiology'),
#  ('A014',
#   'P028',
#   'Jacob Lee',
#   'S016',
#   'Dr. Nisha Tan',
#   '14/08/2024',
#   'Orthopedics'),
#  ('A015',
#   'P039',
#   'Paul Tan',
#   'S015',
#   'Dr. Daniel Lee',
#   '15/08/2024',
#   'General Surgery'),
#  ('A016',
#   'P016',
#   'Tan Cheng',
#   'S014',
#   'Dr. Li Wei',
#   '01/08/2024',
#   'Internal Medicine'),
#  ('A017',
#   'P045',
#   'Linda Tan',
#   'S013',
#   'Dr. Marcus Tan',
#   '02/08/2024',
#   'Cardiology'),
#  ('A018',
#   'P019',
#   'Abdul Rahman',
#   'S018',
#   'Dr. Priya Sharma',
#   '03/08/2024',
#   'Neurology'),
#  ('A019',
#   'P009',
#   'Sharon Ng',
#   'S015',
#   'Dr. Daniel Lee',
#   '04/08/2024',
#   'General Surgery'),
#  ('A020',
#   'P046',
#   'John Tan',
#   'S020',
#   'Dr. Seema Ong',
#   '05/08/2024',
#   'Cardiology'),
#  ('A022',
#   'P006',
#   'Lee Ming',
#   'S002',
#   'Dr. Lim Wei',
#   '07/08/2024',
#   'Orthopedics'),
#  ('A023',
#   'P017',
#   'Ng Wai Hong',
#   'S012',
#   'Dr. Mei Ling',
#   '08/08/2024',
#   'Endocrinology'),
#  ('A024',
#   'P020',
#   'Koh Siew Hong',
#   'S004',
#   'Dr. Chen Ming',
#   '09/08/2024',
#   'Neurology'),
#  ('A025',
#   'P038',
#   'Natalie Ho',
#   'S014',
#   'Dr. Li Wei',
#   '10/08/2024',
#   'Internal Medicine'),
#  ('A026',
#   'P025',
#   'Selina Wong',
#   'S006',
#   'Dr. Tan Cheng',
#   '11/08/2024',
#   'Orthopedics'),
#  ('A027',
#   'P029',
#   'Shirley Lim',
#   'S007',
#   'Dr. Kevin Lim',
#   '12/08/2024',
#   'General Surgery'),
#  ('A028',
#   'P035',
#   'Hari Singh',
#   'S008',
#   'Dr. Samuel Lee',
#   '13/08/2024',
#   'Cardiology'),
#  ('A029',
#   'P047',
#   'Nina Chua',
#   'S009',
#   'Dr. Ryan Tan',
#   '14/08/2024',
#   'Neurology'),
#  ('A030',
#   'P024',
#   'Liang Hui',
#   'S010',
#   'Dr. Ethan Ng',
#   '15/08/2024',
#   'Pediatrics'),
#  ('A031',
#   'P018',
#   'Serena Tan',
#   'S011',
#   'Dr. John Tan',
#   '01/08/2024',
#   'Oncology'),
#  ('A032',
#   'P013',
#   'Daniel Ho',
#   'S012',
#   'Dr. Mei Ling',
#   '02/08/2024',
#   'Endocrinology'),
#  ('A033',
#   'P041',
#   'Emily Lee',
#   'S013',
#   'Dr. Marcus Tan',
#   '03/08/2024',
#   'Cardiology'),
#  ('A035',
#   'P007',
#   'Siti Nur',
#   'S015',
#   'Dr. Daniel Lee',
#   '05/08/2024',
#   'General Surgery'),
#  ('A036',
#   'P030',
#   'Sammy Ong',
#   'S014',
#   'Dr. Li Wei',
#   '06/08/2024',
#   'Internal Medicine'),
#  ('A038',
#   'P032',
#   'Eric Chua',
#   'S018',
#   'Dr. Priya Sharma',
#   '08/08/2024',
#   'Neurology'),
#  ('A041',
#   'P015',
#   'Salmah Khan',
#   'S013',
#   'Dr. Marcus Tan',
#   '11/08/2024',
#   'Cardiology'),
#  ('A042',
#   'P021',
#   'Joan Lim',
#   'S002',
#   'Dr. Lim Wei',
#   '12/08/2024',
#   'Orthopedics'),
#  ('A043',
#   'P022',
#   'Ah Mei',
#   'S012',
#   'Dr. Mei Ling',
#   '13/08/2024',
#   'Endocrinology'),
#  ('A044',
#   'P011',
#   'Lim Ah Kow',
#   'S004',
#   'Dr. Chen Ming',
#   '14/08/2024',
#   'Neurology'),
#  ('A045',
#   'P050',
#   'Alan Ng',
#   'S014',
#   'Dr. Li Wei',
#   '15/08/2024',
#   'Internal Medicine'),
#  ('A047',
#   'P013',
#   'Daniel Ho',
#   'S007',
#   'Dr. Kevin Lim',
#   '02/08/2024',
#   'General Surgery'),
#  ('A049',
#   'P044',
#   'Kevin Ng',
#   'S009',
#   'Dr. Ryan Tan',
#   '04/08/2024',
#   'Neurology'),
#  ('A050',
#   'P018',
#   'Serena Tan',
#   'S010',
#   'Dr. Ethan Ng',
#   '05/08/2024',
#   'Pediatrics'),
#  ('A052',
#   'P041',
#   'Emily Lee',
#   'S012',
#   'Dr. Mei Ling',
#   '07/08/2024',
#   'Endocrinology'),
#  ('A053',
#   'P022',
#   'Ah Mei',
#   'S013',
#   'Dr. Marcus Tan',
#   '08/08/2024',
#   'Cardiology'),
#  ('A054',
#   'P034',
#   'Victor Tan',
#   'S016',
#   'Dr. Nisha Tan',
#   '09/08/2024',
#   'Internal Medicine'),
#  ('A056',
#   'P027',
#   'Fiona Tan',
#   'S014',
#   'Dr. Li Wei',
#   '11/08/2024',
#   'Orthopedics'),
#  ('A058',
#   'P043',
#   'Li Ping',
#   'S018',
#   'Dr. Priya Sharma',
#   '13/08/2024',
#   'Neurology'),
#  ('A059',
#   'P020',
#   'Koh Siew Hong',
#   'S019',
#   'Dr. Ramesh Bhat',
#   '14/08/2024',
#   'Oncology'),
#  ('A060',
#   'P013',
#   'Daniel Ho',
#   'S020',
#   'Dr. Seema Ong',
#   '15/08/2024',
#   'Cardiology'),
#  ('A061',
#   'P023',
#   'Anwar Ali',
#   'S013',
#   'Dr. Marcus Tan',
#   '01/08/2024',
#   'Cardiology'),
#  ('A062',
#   'P012',
#   'Amira Hussain',
#   'S002',
#   'Dr. Lim Wei',
#   '02/08/2024',
#   'Orthopedics'),
#  ('A064',
#   'P030',
#   'Sammy Ong',
#   'S004',
#   'Dr. Chen Ming',
#   '04/08/2024',
#   'Neurology'),
#  ('A065',
#   'P025',
#   'Selina Wong',
#   'S015',
#   'Dr. Daniel Lee',
#   '05/08/2024',
#   'General Surgery'),
#  ('A066',
#   'P037',
#   'Ah Fook',
#   'S014',
#   'Dr. Li Wei',
#   '06/08/2024',
#   'Internal Medicine'),
#  ('A069',
#   'P043',
#   'Li Ping',
#   'S019',
#   'Dr. Ramesh Bhat',
#   '09/08/2024',
#   'Oncology'),
#  ('A070',
#   'P035',
#   'Hari Singh',
#   'S020',
#   'Dr. Seema Ong',
#   '10/08/2024',
#   'Cardiology'),
#  ('A071',
#   'P018',
#   'Serena Tan',
#   'S013',
#   'Dr. Marcus Tan',
#   '11/08/2024',
#   'Cardiology'),
#  ('A072',
#   'P032',
#   'Eric Chua',
#   'S012',
#   'Dr. Mei Ling',
#   '12/08/2024',
#   'Endocrinology'),
#  ('A073',
#   'P007',
#   'Siti Nur',
#   'S015',
#   'Dr. Daniel Lee',
#   '13/08/2024',
#   'General Surgery'),
#  ('A074',
#   'P042',
#   'Ali Abdullah',
#   'S016',
#   'Dr. Nisha Tan',
#   '14/08/2024',
#   'Internal Medicine'),
#  ('A075',
#   'P026',
#   'Victor Cheong',
#   'S014',
#   'Dr. Li Wei',
#   '15/08/2024',
#   'Orthopedics'),
#  ('A076',
#   'P041',
#   'Emily Lee',
#   'S007',
#   'Dr. Kevin Lim',
#   '01/08/2024',
#   'General Surgery'),
#  ('A077',
#   'P020',
#   'Koh Siew Hong',
#   'S017',
#   'Dr. Sanjay Rao',
#   '02/08/2024',
#   'Pediatrics'),
#  ('A078',
#   'P022',
#   'Ah Mei',
#   'S018',
#   'Dr. Priya Sharma',
#   '03/08/2024',
#   'Neurology'),
#  ('A081',
#   'P032',
#   'Eric Chua',
#   'S013',
#   'Dr. Marcus Tan',
#   '06/08/2024',
#   'Cardiology'),
#  ('A082',
#   'P027',
#   'Fiona Tan',
#   'S012',
#   'Dr. Mei Ling',
#   '07/08/2024',
#   'Endocrinology'),
#  ('A083',
#   'P016',
#   'Tan Cheng',
#   'S015',
#   'Dr. Daniel Lee',
#   '08/08/2024',
#   'General Surgery'),
#  ('A084',
#   'P039',
#   'Paul Tan',
#   'S016',
#   'Dr. Nisha Tan',
#   '09/08/2024',
#   'Internal Medicine'),
#  ('A086',
#   'P021',
#   'Joan Lim',
#   'S018',
#   'Dr. Priya Sharma',
#   '11/08/2024',
#   'Neurology'),
#  ('A087',
#   'P040',
#   'Jamie Ong',
#   'S019',
#   'Dr. Ramesh Bhat',
#   '12/08/2024',
#   'Oncology'),
#  ('A088',
#   'P044',
#   'Kevin Ng',
#   'S020',
#   'Dr. Seema Ong',
#   '13/08/2024',
#   'Cardiology'),
#  ('A090',
#   'P001',
#   'Wei Li',
#   'S015',
#   'Dr. Daniel Lee',
#   '15/08/2024',
#   'General Surgery'),
#  ('A091',
#   'P046',
#   'John Tan',
#   'S016',
#   'Dr. Nisha Tan',
#   '01/08/2024',
#   'Internal Medicine'),
#  ('A092',
#   'P043',
#   'Li Ping',
#   'S017',
#   'Dr. Sanjay Rao',
#   '02/08/2024',
#   'Pediatrics'),
#  ('A094',
#   'P049',
#   'Joanne Lim',
#   'S019',
#   'Dr. Ramesh Bhat',
#   '04/08/2024',
#   'Oncology'),
#  ('A096',
#   'P026',
#   'Victor Cheong',
#   'S013',
#   'Dr. Marcus Tan',
#   '06/08/2024',
#   'Cardiology'),
#  ('A097',
#   'P025',
#   'Selina Wong',
#   'S014',
#   'Dr. Li Wei',
#   '07/08/2024',
#   'Orthopedics'),
#  ('A098',
#   'P020',
#   'Koh Siew Hong',
#   'S015',
#   'Dr. Daniel Lee',
#   '08/08/2024',
#   'General Surgery')]

# %%
# Task 4.3: List Staff Workload
import sqlite3

# Connect to the CLINIC.db database
conn = sqlite3.connect('CLINIC.db')
cursor = conn.cursor()

# Execute the SQL query to list staff workload
cursor.execute('''
    SELECT Staff.Name, Staff.Role, COUNT(Appointment.AppointmentID) AS AppointmentCount
    FROM Staff
    LEFT OUTER JOIN Appointment ON Staff.StaffID = Appointment.StaffID
    GROUP BY Staff.StaffID
    ORDER BY Staff.Role, AppointmentCount DESC
''')

# Fetch all the results
workload = cursor.fetchall()

# Close the database connection
conn.close()

# Print the data under suitable headings
print(f"{'Staff Name':<20} {'Role':<15} {'Number of Appointments':<25}")
print("-" * 60)

for row in workload:
    print(f"{row[0]:<20} {row[1]:<15} {row[2]:<25}")
# Out:
# Staff Name           Role            Number of Appointments
# ------------------------------------------------------------
# Dr. Marcus Tan       Doctor          12
# Dr. Mei Ling         Doctor          9
# Dr. Li Wei           Doctor          9
# Dr. Daniel Lee       Doctor          9
# Dr. Nisha Tan        Doctor          7
# Dr. Sanjay Rao       Doctor          7
# Dr. Priya Sharma     Doctor          7
# Dr. Seema Ong        Doctor          7
# Dr. Ramesh Bhat      Doctor          6
# Dr. Lim Wei          Doctor          4
# Dr. Chen Ming        Doctor          4
# Dr. Kevin Lim        Doctor          4
# Dr. Tan Cheng        Doctor          3
# Dr. Samuel Lee       Doctor          3
# Dr. Ryan Tan         Doctor          3
# Dr. Ethan Ng         Doctor          3
# Dr. John Tan         Doctor          3
# Dr. Aiden Tan        Doctor          0
# Dr. Zhang Li         Doctor          0
# Dr. Ong Zhihao       Doctor          0
# Nurse Linda Tan      Nurse           0
# Nurse James Lee      Nurse           0
# Nurse Clara Lim      Nurse           0
# Nurse Michael Ong    Nurse           0
# Nurse Rachel Chua    Nurse           0
# Nurse Daniel Tan     Nurse           0
# Nurse Olivia Teo     Nurse           0
# Nurse Alex Chew      Nurse           0
# Nurse Maria Wong     Nurse           0
# Nurse Kevin Tan      Nurse           0
# Nurse Sophie Ho      Nurse           0
# Nurse Ryan Lee       Nurse           0
# Nurse Jasmine Tan    Nurse           0
# Nurse Adam Lim       Nurse           0
# Nurse Emma Ong       Nurse           0
# Nurse Lucas Tan      Nurse           0
# Nurse Natalie Chia   Nurse           0
# Nurse Max Tan        Nurse           0
# Nurse Ava Tan        Nurse           0
# Nurse Isaac Teo      Nurse           0
# Nurse Mia Wong       Nurse           0
# Nurse Noah Tan       Nurse           0
# Nurse Zoe Lim        Nurse           0
# Nurse William Tan    Nurse           0
# Nurse Ella Chua      Nurse           0
# Nurse Liam Lee       Nurse           0
# Nurse Harper Tan     Nurse           0
# Nurse Ethan Ong      Nurse           0
# Nurse Charlotte Tan  Nurse           0
# Nurse Oliver Chia    Nurse           0
# Nurse Grace Teo      Nurse           0
# Nurse Jacob Lee      Nurse           0
# Nurse Amelia Wong    Nurse           0
# Nurse Leo Tan        Nurse           0
# Nurse Isabella Lim   Nurse           0
# Nurse Henry Tan      Nurse           0
# Nurse Lily Ong       Nurse           0
# Nurse Jack Tan       Nurse           0
# Nurse Chloe Tan      Nurse           0
# Nurse Aiden Lee      Nurse           0
# Ms. Fiona Lim        Technician      0
# Ms. Grace Tan        Technician      0
# Ms. Emily Chen       Technician      0
# Ms. Sarah Ng         Technician      0
# Ms. Lily Koh         Technician      0
