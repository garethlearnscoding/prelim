# %%
# Task3.1
alien_codes = ['205166226166220203211216231216', '224166214166220166200210', '200166220203226216', '214166214216212166226166226203', '214216226225204216214225226225', '205216212166211216212166', '212210212203212166226225', '211225202203220225212210215216', '226216226225205166226203', '213225212203220166226166', '226225213203226225200166', '220203212216211225', '212166220216212216', '231225220210', '212166205216226203', '211216220225212166226225', '204225212166212203226225', '214166222166211216226203', '221166220210211216', '230216214203226225', '230203200216220166', '226216212225214216', '231166211225220225', '202225226203220225', '230203226225', '220216231216226203', '226216212225226225', '212166212225214203', '200216226225', '233216211203', '205166212210', '230203211225', '214210202225220225', '224216224225211166226203', '224210212225226225', '233166211225212166226210', '200203212216212210200203', '233210220225230225', '226216202225226225', '213225202203212225', '226225212203212210', '226216220166212203226225', '200225205216205216', '213166233166226210', '215225220166212203', '214203231216226203', '212203205166212225', '214216212225211203', '233225230225', '230166233225212225220166', '202225200203226225', '215225212203214210', '212225205225214203', '221166212225214166226210', '205225220216220203', '212216211166211203', '233225224166212216226225', '220225200210212225', '214216212225215225', '226225200166220203220216', '202225200166220203226225', '212225200166214166', '211216212210212216212225', '205210220216212203', '215225220166226225', '205166212225226225', '211225212225214225', '200166202225212210', '233166212166212216226203', '233225211166214203', '214216212166226216220166', '212210220166226203', '202166214203220225', '233225220225226225', '220225212166211210', '220225212166214166211203', '213166220166226203', '212216214225212225', '230166233166226166212203', '233225211166212203', '226166211166212203', '233225233225214225', '205225226166211203', '215225212225220210', '202166226203226225200203', '214225226166212216', '205225212216214203', '213216221203212225', '221216212166220225212203', '213225233166212203226225', '211216212166226210', '213216214225212203', '215210220166211203', '220216214216212225', '233216212225214203', '212210202166220216212225', '220225214203212166226225', '214203233166211166226225', '202225226203212203214225', '233166220166212203214225']

def display_alien_words(alien_codes):
    pass
        
display_alien_words(alien_codes)

# %%
# Task3.2
class AlienKnowledgeDataBase():
    def __init__(self, known_alien_word_list):
        pass
            
    def search(self, alien_word): # O(lg n) time
        pass

alien_words_100 = [
    "gavapejoxo", "tamapabi", "bapevo", "mamokavave", "movufomuvu", "gokajoka", "kikekavu",
    "judepukino", "vovugave", "lukepava", "vulevuba", "pekoju", "kapoko", "xupi", "kagove",
    "jopukavu", "fukakevu", "marajove", "qapijo", "womevu", "webopa", "vokumo", "xajupu",
    "duvepu", "wevu", "poxove", "vokuvu", "kakume", "bovu", "zoje", "gaki", "weju", "midupu",
    "totujave", "tikuvu", "zajukavi", "bekokibe", "zipuwu", "voduvu", "ludeku", "vukeki",
    "vopakevu", "bugogo", "lazavi", "nupake", "mexove", "kegaku", "mokuje", "zuwu", "wazukupa",
    "dubevu", "nukemi", "kugume", "qakumavi", "gupope", "kojaje", "zutakovu", "pubiku",
    "mokunu", "vubapepo", "dubapevu", "kubama", "jokikoku", "gipoke", "nupavu", "gakuvu",
    "jukumu", "baduki", "zakakove", "zujame", "mokavopa", "kipave", "damepu", "zupuvu",
    "pukaji", "pukamaje", "lapave", "komuku", "wazavake", "zujake", "vajake", "zuzumu",
    "guvaje", "nukupi", "davevube", "muvako", "gukome", "loqeku", "qokapuke", "luzakevu",
    "jokavi", "lomuke", "nipaje", "pomoku", "zokume", "kidapoku", "pumekavu", "mezajavu",
    "duvekemu", "zapakemu"
]

known_alien_word_list = ['gavapejoxo', 'bapevo', 'movufomuvu', 'kikekavu', 'vovugave', 'vulevuba', 'kapoko', 'kagove', 'fukakevu', 'qapijo', 'webopa', 'xajupu', 'wevu', 'vokuvu', 'bovu', 'gaki', 'midupu', 'tikuvu', 'bekokibe', 'voduvu', 'vukeki', 'bugogo', 'nupake', 'kegaku', 'zuwu', 'dubevu', 'kugume', 'gupope', 'zutakovu', 'mokunu', 'dubapevu', 'jokikoku', 'nupavu', 'jukumu', 'zakakove', 'mokavopa', 'damepu', 'pukaji', 'lapave', 'wazavake', 'vajake', 'guvaje', 'davevube', 'gukome', 'qokapuke', 'jokavi', 'nipaje', 'zokume', 'pumekavu']
    

def task3_2(): # This is the test case for 3.2
    akd = AlienKnowledgeDataBase(known_alien_word_list)
    result = []
    for alien_word in alien_words_100:
        if not akd.search(alien_word):
            result.append(alien_word)
    print("There are " + str(len(result)) + " unknown alien words found:")
    print(result)

task3_2()

# %%
# Task3.3
class AlienKnowledgeDataBase2():
    
    def __init__(self, known_alien_word_list):  
        pass
            
            
    def search(self, alien_word): # O(1) time
        pass
        

def task3_3(): # This is the test case for 3.3
    akd = AlienKnowledgeDataBase2(known_alien_word_list)
    result = []
    for alien_word in alien_words_100:
        if not akd.search(alien_word):
            result.append(alien_word)
    print("There are " + str(len(result)) + " unknown alien words found:")
    print(result)

task3_3()
